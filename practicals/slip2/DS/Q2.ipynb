# %% [markdown]
# ##### Q.2 A) Write a Python program for Handling Missing Value. Replace missing value of salary, age column with mean of that column.(Use Data.csv file).

# %%
import pandas as pd 
import matplotlib.pyplot as plt
df  = pd.read_csv("./data1.csv")
df.head()

df['Salary'].fillna(df['Salary'].mean() , inplace=True)

df.head()
# Out:
#   Employee  Age   Salary Purchased
# 0   Anjali   45  71000.0        No
# 1    Parul   28  48000.0       Yes
# 2  Kanisha   31  53000.0        No
# 3    Sahil   35  61000.0        No
# 4    Rohan   42  58250.0       Yes

# %% [markdown]
# ##### Q.2  B) Write a Python program to generate a line plot of name Vs salary

# %%
plt.plot(df['Employee'] , df['Salary'])
plt.show()

# %% [markdown]
# ##### Q.2 C) Download the heights and weights dataset and load the dataset froma given csv file into a dataframe. Print the first, last 10 rows and random 20 rows also display shape of the dataset.

# %%
import pandas as pd;
import random

df = pd.read_csv("./HeightWeight.csv")

print(df.head(10))

print(df.sample(20))

print(df.shape)
# Out:
#    Index    Height    Weight
# 0      1  65.78331  112.9925
# 1      2  71.51521  136.4873
# 2      3  69.39874  153.0269
# 3      4  68.21660  142.3354
# 4      5  67.78781  144.2971
# 5      6  68.69784  123.3024
# 6      7  69.80204  141.4947
# 7      8  70.01472  136.4623
# 8      9  67.90265  112.3723
# 9     10  66.78236  120.6672
#        Index    Height    Weight
# 19771  19772  69.13771  134.5773
# 11633  11634  69.61676  121.0389
# 7154    7155  67.18007  126.0652
# 17461  17462  66.75222  128.8606
# 10225  10226  66.19577  126.6438
# 18686  18687  67.07489  116.9079
# 18907  18908  70.17018  146.3284
# 11200  11201  67.77124  119.2235
# 12940  12941  68.20520  120.8053
# 6300    6301  65.53954  119.8531
# 14870  14871  69.32049  127.5045
# 13082  13083  70.04568  118.2566
# 9124    9125  67.28386  141.0113
# 12134  12135  67.07331  130.6017
# 20966  20967  73.47464  134.9960
# 9719    9720  70.85706  123.5573
# 16053  16054  69.84558  130.0924
# 16522  16523  64.62832  138.6254
# 21029  21030  69.46283  118.5577
# 13247  13248  69.86294  123.7869
# (25000, 3)
